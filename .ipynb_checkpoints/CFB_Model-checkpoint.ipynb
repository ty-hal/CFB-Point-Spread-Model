# %%
import requests
import numpy as np
import pandas as pd
import pickle

# Range of years
start_year = 2015
end_year = 2023
current_year = 2023

# %%
# Method to conviently fetch data from different CFBD endpoints 
def get_api_data(endpoint, params=None):
    base_url = "https://api.collegefootballdata.com"
    url = base_url + endpoint

    api_key = "h2jcXh77WoIog0ba1MdofV5zcg0L0I8NHC3EMmnymPP5G3xF/LxHn+x3asvvSIo2"

    headers = {
        "Authorization": f"Bearer {api_key}"
    }

    response = requests.get(url, params=params, headers=headers)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Request failed with status code: {response.status_code}")
        return None

# %%
# List to store game data
games = []

# Iterate through the years, make API requests, and only collect the relevant features
for year in range(start_year, end_year + 1):
    params = {
        "year": year,
        "seasonType": "regular",
    }
    
    games_data = get_api_data("/games", params)

    # Checking if the request was successful (status code 200)
    if games_data:
        for g in games_data:
            if g['home_conference'] is not None and g['away_conference'] is not None and g['home_points'] is not None and g['away_points'] is not None:
                games.append({
                    'id': g['id'],
                    'year': g['season'],
                    'week': g['week'],
                    'neutral_site': g['neutral_site'],
                    'home_team': g['home_team'],
                    'home_conference': g['home_conference'],
                    'home_points': g['home_points'],
                    'home_elo': g['home_pregame_elo'],
                    'away_team': g['away_team'],
                    'away_conference': g['away_conference'],
                    'away_points': g['away_points'],
                    'away_elo': g['away_pregame_elo']
                })

# Create a DataFrame from the list of game data
data = pd.DataFrame(games).dropna()
data['margin'] = data['away_points'] - data['home_points']
data.head()
# Out:
#            id  year  week  neutral_site         home_team    home_conference
# 1   400763593  2015     1         False               UCF  American Athletic  \
# 2   400603840  2015     1          True    South Carolina                SEC
# 4   400763399  2015     1         False  Central Michigan       Mid-American
# 15  400603839  2015     1         False        Vanderbilt                SEC
# 16  400756883  2015     1         False              Utah             Pac-12
#
#     home_points  home_elo              away_team away_conference  away_points
# 1            14    1626.0  Florida International  Conference USA           15  \
# 2            17    1646.0         North Carolina             ACC           13
# 4            13    1417.0         Oklahoma State          Big 12           24
# 15           12    1365.0       Western Kentucky  Conference USA           14
# 16           24    1603.0               Michigan         Big Ten           17
#
#     away_elo  margin
# 1     1321.0       1
# 2     1477.0      -4
# 4     1567.0      11
# 15    1521.0       2
# 16    1553.0      -7

# %%
# Collect data for the consensus spread of the games
for year in range(start_year, end_year + 1):
    params = {
        "year": year
    }
    
    betting_data = get_api_data("/lines", params)

    for betting_line in betting_data:
        if betting_line['lines'] and any(l['provider'] == 'consensus' for l in betting_line['lines']):
            consensus_spread = next(l['spread'] for l in betting_line['lines'] if l['provider'] == 'consensus')
            data.loc[data['id'] == betting_line['id'], 'spread'] = float(consensus_spread) if consensus_spread is not None else None

data.head()
# Out:
#            id  year  week  neutral_site         home_team    home_conference
# 1   400763593  2015     1         False               UCF  American Athletic  \
# 2   400603840  2015     1          True    South Carolina                SEC
# 4   400763399  2015     1         False  Central Michigan       Mid-American
# 15  400603839  2015     1         False        Vanderbilt                SEC
# 16  400756883  2015     1         False              Utah             Pac-12
#
#     home_points  home_elo              away_team away_conference  away_points
# 1            14    1626.0  Florida International  Conference USA           15  \
# 2            17    1646.0         North Carolina             ACC           13
# 4            13    1417.0         Oklahoma State          Big 12           24
# 15           12    1365.0       Western Kentucky  Conference USA           14
# 16           24    1603.0               Michigan         Big Ten           17
#
#     away_elo  margin  spread
# 1     1321.0       1   -17.0
# 2     1477.0      -4    -3.5
# 4     1567.0      11    20.5
# 15    1521.0       2   -17.5
# 16    1553.0      -7    -3.0

# %%
# Create a dictionary to collect roster talent data
talent_dict = {}

# Collect data for the 247 roster talent ratings
for year in range(start_year, end_year + 1):
    params = {
        "year": year
    }
    
    talent_data = get_api_data("/talent", params)

    for talent in talent_data:
        key = (talent['school'], talent['year'])
        if key not in talent_dict:
            talent_dict[key] = talent['talent']

# Map the talent data to the DataFrame based on 'school' and 'year'
data['home_talent'] = data.apply(lambda row: talent_dict.get((row['home_team'], row['year']), None), axis=1)
data['away_talent'] = data.apply(lambda row: talent_dict.get((row['away_team'], row['year']), None), axis=1)

data.head()
# Out:
#            id  year  week  neutral_site         home_team    home_conference
# 1   400763593  2015     1         False               UCF  American Athletic  \
# 2   400603840  2015     1          True    South Carolina                SEC
# 4   400763399  2015     1         False  Central Michigan       Mid-American
# 15  400603839  2015     1         False        Vanderbilt                SEC
# 16  400756883  2015     1         False              Utah             Pac-12
#
#     home_points  home_elo              away_team away_conference  away_points
# 1            14    1626.0  Florida International  Conference USA           15  \
# 2            17    1646.0         North Carolina             ACC           13
# 4            13    1417.0         Oklahoma State          Big 12           24
# 15           12    1365.0       Western Kentucky  Conference USA           14
# 16           24    1603.0               Michigan         Big Ten           17
#
#     away_elo  margin  spread home_talent away_talent
# 1     1321.0       1   -17.0      484.54      360.11
# 2     1477.0      -4    -3.5      725.72      683.03
# 4     1567.0      11    20.5      376.81      651.83
# 15    1521.0       2   -17.5      609.76      353.50
# 16    1553.0      -7    -3.0      574.41      851.12

# %%
# Create a dictionary to collect poll ranking data
rankings_dict = {}

# Only consider the AP Top 25 poll and Coaches Poll
unique_poll_names = set(['AP Top 25', 'Coaches Poll'])

# Collect data for the polls
for year in range(start_year, end_year + 1):
    params = {
        "year": year
    }
    
    rankings_data = get_api_data("/rankings", params)

    for rr in rankings_data:
        for poll in rr['polls']:
            if poll['poll'] in unique_poll_names:
                for rank in poll['ranks']:
                    key = (rank['school'], rr['season'], rr['week'], poll['poll'])
                    rankings_dict[key] = rank['points']

# Map the ranking data to the DataFrame based on 'home_team' or 'away_team', 'year', and 'week'
for poll_name in unique_poll_names:
    home_column_name = f'home_{poll_name.replace(" ", "_").lower()}_points'
    away_column_name = f'away_{poll_name.replace(" ", "_").lower()}_points'
    data[home_column_name] = data.apply(
        lambda row: rankings_dict.get((row['home_team'], row['year'], row['week'], poll_name), 0),
        axis=1
    )
    data[away_column_name] = data.apply(
        lambda row: rankings_dict.get((row['away_team'], row['year'], row['week'], poll_name), 0),
        axis=1
    )
    
data.head()
# Out:
#            id  year  week  neutral_site         home_team    home_conference
# 1   400763593  2015     1         False               UCF  American Athletic  \
# 2   400603840  2015     1          True    South Carolina                SEC
# 4   400763399  2015     1         False  Central Michigan       Mid-American
# 15  400603839  2015     1         False        Vanderbilt                SEC
# 16  400756883  2015     1         False              Utah             Pac-12
#
#     home_points  home_elo              away_team away_conference  away_points
# 1            14    1626.0  Florida International  Conference USA           15  \
# 2            17    1646.0         North Carolina             ACC           13
# 4            13    1417.0         Oklahoma State          Big 12           24
# 15           12    1365.0       Western Kentucky  Conference USA           14
# 16           24    1603.0               Michigan         Big Ten           17
#
#     away_elo  margin  spread home_talent away_talent
# 1     1321.0       1   -17.0      484.54      360.11  \
# 2     1477.0      -4    -3.5      725.72      683.03
# 4     1567.0      11    20.5      376.81      651.83
# 15    1521.0       2   -17.5      609.76      353.50
# 16    1553.0      -7    -3.0      574.41      851.12
#
#     home_coaches_poll_points  away_coaches_poll_points  home_ap_top_25_points
# 1                          0                         0                      0  \
# 2                          0                         0                      0
# 4                          0                         0                      0
# 15                         0                         0                      0
# 16                         0                         0                      0
#
#     away_ap_top_25_points
# 1                       0
# 2                       0
# 4                       0
# 15                      0
# 16                      0

# %%
# Collect data for the cumulative basic stats for each team for each week (e.g. number of turnovers from weeks 1 to 5 in the week 6 row)
max_week = data['week'].max()
season_stats_dict = {}
# Only get these basic stats
stat_name_mappings = {
    'possessionTime': 'possession_time',
    'turnovers': 'turnovers',
    'penalties': 'penalties',
    'sacks': 'sacks',
    'tacklesForLoss': 'tackles_for_loss',
    'firstDowns': 'first_downs',
    'passingTDs': 'passingsTDs',
    'rushingTDs': 'rushingTDs'
}

# Collect the basic stats data
for year in range(start_year, end_year + 1):
    print("Fetching data for year: ", year)
    for week in range (1, max_week):
        params = {
            "year": year,
            "startWeek": 1,
            "endWeek": week
        }
        season_stats_data = get_api_data("/stats/season", params)
        
        for team_stat in season_stats_data:
            if 'statName' in team_stat and team_stat['statName'] in stat_name_mappings:
                key = (team_stat['team'], team_stat['season'], week, stat_name_mappings[team_stat['statName']])
                season_stats_dict[key] = team_stat['statValue']
                
# Map the basic stats data to the teams, offset by a week to not include the current week's data
for stat in stat_name_mappings.values():
    home_column_name = f'home_cumulative_{stat}'
    away_column_name = f'away_cumulative_{stat}'
    data[home_column_name] = data.apply(
        lambda row: season_stats_dict.get((row['home_team'], row['year'], row['week'] - 1, stat), 0),
        axis=1
    )
    data[away_column_name] = data.apply(
        lambda row: season_stats_dict.get((row['away_team'], row['year'], row['week'] - 1, stat), 0),
        axis=1
    )

# Since the head would have 0 for all of the stats since it's the first game of the season, look by a team
data[(data['year'] == 2022) & ((data['home_team'] == 'Florida') | (data['away_team'] == 'Florida'))]
# Out:
# Fetching data for year:  2015
# Fetching data for year:  2016
# Fetching data for year:  2017
# Fetching data for year:  2018
# Fetching data for year:  2019
# Fetching data for year:  2020
# Fetching data for year:  2021
# Fetching data for year:  2022
# Fetching data for year:  2023
#               id  year  week  neutral_site      home_team home_conference
# 10655  401403857  2022     1         False        Florida             SEC  \
# 10948  401403871  2022     2         False        Florida             SEC
# 11274  401403883  2022     3         False        Florida             SEC
# 11476  401403901  2022     4         False      Tennessee             SEC
# 11905  401403910  2022     6         False        Florida             SEC
# 12459  401403917  2022     7         False        Florida             SEC
# 13032  401403928  2022     9          True        Georgia             SEC
# 13110  401403937  2022    10         False      Texas A&M             SEC
# 13390  401403941  2022    11         False        Florida             SEC
# 13441  401403955  2022    12         False     Vanderbilt             SEC
# 13584  401403958  2022    13         False  Florida State             ACC
#
#        home_points  home_elo       away_team    away_conference  ...
# 10655           29    1572.0            Utah             Pac-12  ...  \
# 10948           16    1576.0        Kentucky                SEC  ...
# 11274           31    1567.0   South Florida  American Athletic  ...
# 11476           38    1835.0         Florida                SEC  ...
# 11905           24    1569.0        Missouri                SEC  ...
# 12459           35    1572.0             LSU                SEC  ...
# 13032           42    2154.0         Florida                SEC  ...
# 13110           24    1655.0         Florida                SEC  ...
# 13390           38    1604.0  South Carolina                SEC  ...
# 13441           31    1298.0         Florida                SEC  ...
# 13584           45    1851.0         Florida                SEC  ...
#
#        home_cumulative_sacks  away_cumulative_sacks
# 10655                      0                      0  \
# 10948                      0                      3
# 11274                      3                      4
# 11476                      8                      3
# 11905                      8                     11
# 12459                     12                     15
# 13032                      7                     13
# 13110                     13                     13
# 13390                     15                     13
# 13441                     17                     18
# 13584                     32                     19
#
#        home_cumulative_tackles_for_loss  away_cumulative_tackles_for_loss
# 10655                                 0                                 0  \
# 10948                                 2                                 4
# 11274                                 8                                18
# 11476                                22                                12
# 11905                                24                                34
# 12459                                37                                31
# 13032                                31                                40
# 13110                                43                                43
# 13390                                49                                43
# 13441                                51                                56
# 13584                                70                                61
#
#       home_cumulative_first_downs away_cumulative_first_downs
# 10655                           0                           0  \
# 10948                          23                          20
# 11274                          35                          32
# 11476                          80                          52
# 11905                         103                          88
# 12459                         116                         139
# 13032                         190                         135
# 13110                         158                         151
# 13390                         179                         166
# 13441                         175                         205
# 13584                         263                         225
#
#        home_cumulative_passingsTDs  away_cumulative_passingsTDs
# 10655                            0                            0  \
# 10948                            0                            3
# 11274                            0                            0
# 11476                            9                            0
# 11905                            5                            5
# 12459                            6                            8
# 13032                           11                            7
# 13110                           13                            8
# 13390                           10                           11
# 13441                           19                           12
# 13584                           25                           15
#
#        home_cumulative_rushingTDs  away_cumulative_rushingTDs
# 10655                           0                           0
# 10948                           4                           0
# 11274                           5                           8
# 11476                          12                           8
# 11905                          15                           8
# 12459                          16                          16
# 13032                          24                          20
# 13110                           7                          21
# 13390                          24                          22
# 13441                          13                          27
# 13584                          26                          27
#
# [11 rows x 36 columns]

# %%
# Save the dataframe to a pickle file to avoid repeatedly recreating the dataframe
with open('dataframe.pickle', 'wb') as file:
    pickle.dump(data, file)

# %%
# Load the dataframe
with open('dataframe.pickle', 'rb') as file:
    data = pickle.load(file)

print(data.shape)
# Out:
# (5649, 36)

# %%
test_df = data.query("year == 2022")
train_df = data.query("year < 2022")

# %%
excluded = ['id','year','week','home_team','away_team','margin', 'home_points', 'away_points']
cat_features = ['home_conference','away_conference','neutral_site']
cont_features = [c for c in data.columns.to_list() if c not in cat_features and c not in excluded]

# %%
# !pip install fastai --user
# Out:
# Requirement already satisfied: fastai in c:\users\tyhal\appdata\roaming\python\python311\site-packages (2.7.12)
# Requirement already satisfied: pip in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from fastai) (22.3.1)
# Requirement already satisfied: packaging in c:\python311\lib\site-packages (from fastai) (22.0)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from fastai) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from fastai) (1.5.29)
# Requirement already satisfied: torchvision>=0.8.2 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from fastai) (0.15.2)
# Requirement already satisfied: matplotlib in c:\python311\lib\site-packages (from fastai) (3.7.1)
# Requirement already satisfied: pandas in c:\python311\lib\site-packages (from fastai) (2.0.0)
# Requirement already satisfied: requests in c:\python311\lib\site-packages (from fastai) (2.28.1)
# Requirement already satisfied: pyyaml in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from fastai) (6.0.1)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from fastai) (1.0.3)
# Requirement already satisfied: pillow>6.0.0 in c:\python311\lib\site-packages (from fastai) (9.4.0)
# Requirement already satisfied: scikit-learn in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from fastai) (1.3.0)
# Requirement already satisfied: scipy in c:\python311\lib\site-packages (from fastai) (1.10.0)
# Requirement already satisfied: spacy<4 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from fastai) (3.6.1)
# Requirement already satisfied: torch<2.1,>=1.7 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from fastai) (2.0.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from spacy<4->fastai) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from spacy<4->fastai) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\python311\lib\site-packages (from spacy<4->fastai) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from spacy<4->fastai) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from spacy<4->fastai) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\python311\lib\site-packages (from spacy<4->fastai) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from spacy<4->fastai) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from spacy<4->fastai) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from spacy<4->fastai) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from spacy<4->fastai) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from spacy<4->fastai) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\python311\lib\site-packages (from spacy<4->fastai) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\python311\lib\site-packages (from spacy<4->fastai) (1.24.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from spacy<4->fastai) (2.3.0)
# Requirement already satisfied: jinja2 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from spacy<4->fastai) (3.1.2)
# Requirement already satisfied: setuptools in c:\python311\lib\site-packages (from spacy<4->fastai) (65.5.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from spacy<4->fastai) (3.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\python311\lib\site-packages (from requests->fastai) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\python311\lib\site-packages (from requests->fastai) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python311\lib\site-packages (from requests->fastai) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python311\lib\site-packages (from requests->fastai) (2022.9.24)
# Requirement already satisfied: filelock in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from torch<2.1,>=1.7->fastai) (3.12.3)
# Requirement already satisfied: typing-extensions in c:\python311\lib\site-packages (from torch<2.1,>=1.7->fastai) (4.7.1)
# Requirement already satisfied: sympy in c:\python311\lib\site-packages (from torch<2.1,>=1.7->fastai) (1.12)
# Requirement already satisfied: networkx in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from torch<2.1,>=1.7->fastai) (3.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python311\lib\site-packages (from matplotlib->fastai) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\python311\lib\site-packages (from matplotlib->fastai) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python311\lib\site-packages (from matplotlib->fastai) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python311\lib\site-packages (from matplotlib->fastai) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python311\lib\site-packages (from matplotlib->fastai) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python311\lib\site-packages (from matplotlib->fastai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python311\lib\site-packages (from pandas->fastai) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\python311\lib\site-packages (from pandas->fastai) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from scikit-learn->fastai) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python311\lib\site-packages (from scikit-learn->fastai) (3.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (2.6.3)
# Requirement already satisfied: six>=1.5 in c:\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai) (0.1.1)
# Requirement already satisfied: colorama in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4->fastai) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from typer<0.10.0,>=0.3.0->spacy<4->fastai) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tyhal\appdata\roaming\python\python311\site-packages (from jinja2->spacy<4->fastai) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\python311\lib\site-packages (from sympy->torch<2.1,>=1.7->fastai) (1.3.0)
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from fastai.tabular import *
from fastai.tabular.all import *

splits = RandomSplitter(valid_pct=0.2)(range_of(train_df))
splits
# Out:
# ((#3928) [4807,3748,117,1485,4459,856,3251,786,2004,1862...],
#  (#982) [2444,2484,1272,2883,4677,1332,3737,2384,1925,4767...])

# %%
to = TabularPandas(train_df, procs=[Categorify, Normalize],
                    y_names="margin",
                    cat_names = cat_features,
                    cont_names = cont_features,
                   splits=splits)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 to = TabularPandas(train_df, procs=[Categorify, Normalize],
#       2                     y_names="margin",
#       3                     cat_names = cat_features,
#       4                     cont_names = cont_features,
#       5                    splits=splits)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\fastai\tabular\core.py:168, in Tabular.__init__(self, df, procs, cat_names, cont_names, y_names, y_block, splits, do_setup, device, inplace, reduce_memory)
#     166 self.cat_names,self.cont_names,self.procs = L(cat_names),L(cont_names),Pipeline(procs)
#     167 self.split = len(df) if splits is None else len(splits[0])
# --> 168 if do_setup: self.setup()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\fastai\tabular\core.py:179, in Tabular.setup(self)
# --> 179 def setup(self): self.procs.setup(self)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\fastcore\transform.py:200, in Pipeline.setup(self, items, train_setup)
#     198 tfms = self.fs[:]
#     199 self.fs.clear()
# --> 200 for t in tfms: self.add(t,items, train_setup)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\fastcore\transform.py:204, in Pipeline.add(self, ts, items, train_setup)
#     202 def add(self,ts, items=None, train_setup=False):
#     203     if not is_listy(ts): ts=[ts]
# --> 204     for t in ts: t.setup(items, train_setup)
#     205     self.fs+=ts
#     206     self.fs = self.fs.sorted(key='order')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\fastcore\transform.py:87, in Transform.setup(self, items, train_setup)
#      85 def setup(self, items=None, train_setup=False):
#      86     train_setup = train_setup if self.train_setup is None else self.train_setup
# ---> 87     return self.setups(getattr(items, 'train', items) if train_setup else items)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\fastcore\dispatch.py:120, in TypeDispatch.__call__(self, *args, **kwargs)
#     118 elif self.inst is not None: f = MethodType(f, self.inst)
#     119 elif self.owner is not None: f = MethodType(f, self.owner)
# --> 120 return f(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\fastai\tabular\core.py:273, in setups(self, to)
#     271 @Normalize
#     272 def setups(self, to:Tabular):
# --> 273     store_attr(but='to', means=dict(getattr(to, 'train', to).conts.mean()),
#     274                stds=dict(getattr(to, 'train', to).conts.std(ddof=0)+1e-7))
#     275     return self(to)
#
# File C:\Python311\Lib\site-packages\pandas\core\generic.py:11563, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11546 @doc(
#   11547     _num_doc,
#   11548     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11561     **kwargs,
#   11562 ):
# > 11563     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File C:\Python311\Lib\site-packages\pandas\core\generic.py:11208, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11201 def mean(
#   11202     self,
#   11203     axis: Axis | None = 0,
#    (...)
#   11206     **kwargs,
#   11207 ) -> Series | float:
# > 11208     return self._stat_function(
#   11209         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11210     )
#
# File C:\Python311\Lib\site-packages\pandas\core\generic.py:11165, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11161     nv.validate_stat_func((), kwargs, fname=name)
#   11163 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11165 return self._reduce(
#   11166     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11167 )
#
# File C:\Python311\Lib\site-packages\pandas\core\frame.py:10519, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10515     df = df.T
#   10517 # After possibly _get_data and transposing, we are now in the
#   10518 #  simple case where we can use BlockManager.reduce
# > 10519 res = df._mgr.reduce(blk_func)
#   10520 out = df._constructor(res).iloc[0]
#   10521 if out_dtype is not None:
#
# File C:\Python311\Lib\site-packages\pandas\core\internals\managers.py:1534, in BlockManager.reduce(self, func)
#    1532 res_blocks: list[Block] = []
#    1533 for blk in self.blocks:
# -> 1534     nbs = blk.reduce(func)
#    1535     res_blocks.extend(nbs)
#    1537 index = Index([None])  # placeholder
#
# File C:\Python311\Lib\site-packages\pandas\core\internals\blocks.py:339, in Block.reduce(self, func)
#     333 @final
#     334 def reduce(self, func) -> list[Block]:
#     335     # We will apply the function and reshape the result into a single-row
#     336     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     337     assert self.ndim == 2
# --> 339     result = func(self.values)
#     341     if self.values.ndim == 1:
#     342         # TODO(EA2D): special case not needed with 2D EAs
#     343         res_values = np.array([[result]])
#
# File C:\Python311\Lib\site-packages\pandas\core\frame.py:10480, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   10476     if not is_1d_only_ea_dtype(values.dtype) and not isinstance(
#   10477         self._mgr, ArrayManager
#   10478     ):
#   10479         return values._reduce(name, axis=1, skipna=skipna, **kwds)
# > 10480     return values._reduce(name, skipna=skipna, **kwds)
#   10481 else:
#   10482     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File C:\Python311\Lib\site-packages\pandas\core\arrays\base.py:1440, in ExtensionArray._reduce(self, name, skipna, **kwargs)
#    1438 meth = getattr(self, name, None)
#    1439 if meth is None:
# -> 1440     raise TypeError(
#    1441         f"'{type(self).__name__}' with dtype {self.dtype} "
#    1442         f"does not support reduction '{name}'"
#    1443     )
#    1444 return meth(skipna=skipna, **kwargs)
#
# TypeError: 'Categorical' with dtype category does not support reduction 'mean'

# %%
dls = to.dataloaders(bs=64)
dls.show_batch()

# %%
learn = tabular_learner(dls, metrics=mae, lr=0.1)
learn

# %%
# learn.lr_find()
learn.fit(10)
learn.show_results()
